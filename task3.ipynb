# %% [markdown]
# ## Exploratory Data Analysis on super store

# %% [markdown]
# <h3>Objective</h3>

# %% [markdown]
# > The objective of this task is to analyse the data of Super store and try to find out the weak areas where we can work to
# make more profit.

# %% [markdown]
# #### Language : Python
# ### <B> by : YOGITA PAPNEY</B>

# %% [markdown]
# <h4>Import libraries</h4>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb

# %% [markdown]
# <h4>Fetch data</h4>

# %%
df=pd.read_csv("C:/Users/HP/Desktop/grip/task3/SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# <h4>Information about data</h4>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 702.8+ KB

# %%
df.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# * <b>By this we get that we have 5 numeric and 8 categorical columns </b>

# %% [markdown]
# <h4>Finding and removing the duplicate data</h4>

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (9977, 13)

# %% [markdown]
# * <b>It shows that in the given dataset we have 17 duplicate rows.which we removed with the help of drop_duplicacy (). </b>

# %% [markdown]
# <h4>Removing extra columns</h4>

# %% [markdown]
# <b>After doing all the above operations I conclude that Country column has only single value and the Postal Code column can be neglected.
#     so we are going to remove both the columns.<b>

# %%
df.drop(['Country','Postal Code'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (9977, 11)

# %% [markdown]
# <h4>Checking null value</h4>

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
#   * <B> Now our dataset looks clean there is no any missing value and duplicacy.</B>

# %% [markdown]
# <H4>Checking categories of features</H4>
# <h4>Univariate analysis</h4>

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sb.countplot(x='Ship Mode',data=df)
plt.show()

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
plt.pie(x=df['Segment'].value_counts(),labels=df['Segment'].unique(),data=df)
plt.show()

# %%
df['City'].value_counts()
# Out:
# New York City        914
# Los Angeles          746
# Philadelphia         536
# San Francisco        506
# Seattle              424
#                     ...
# Arlington Heights      1
# Holyoke                1
# Goldsboro              1
# Orland Park            1
# Keller                 1
# Name: City, Length: 531, dtype: int64

# %%
df['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
plt.figure(figsize=(20,15))
sb.countplot(x='State',data=df)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# * <b>With the help of visualization we can clearly see the variation.Some of the states like California,Texas,New York are performing very well in business
# where as the countries like Wyoming and west virginia are least performing countries.</b>

# %%
df['Region'].value_counts()
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
sb.countplot(x='Region',data=df)
plt.xticks(rotation=70)
plt.show()

# %%
plt.pie(x=df['Region'].value_counts(),labels=['West','East','Central','South'],autopct='%.2f')
plt.show()

# %% [markdown]
# * <b>West region has maximum participation whereas South region has minimum participation in the business.</b>

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
sb.countplot(x='Category',data=df)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# * <b>From all the product categories Office supplies ordered the most.</b>

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,8))
sb.countplot(x='Sub-Category',data=df)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# * <b>Here we can clearly see that the Binders and the paper are the highest demanding sub category which is of the office supplies category.</b>

# %%
df['Sales'].value_counts()
# Out:
# 12.960     55
# 19.440     37
# 15.552     37
# 10.368     35
# 25.920     34
#            ..
# 14.720      1
# 376.866     1
# 572.800     1
# 3.928       1
# 629.640     1
# Name: Sales, Length: 5825, dtype: int64

# %%
plt.figure(figsize=(15,8))
sb.distplot(df['Profit'])
plt.show()

# %% [markdown]
# <h4>Bivariate analysis of profit column with the rest of the columns</h4>

# %%
# visualization between state and profit column

plt.figure(figsize=(20,10))
df_group=df.groupby(["State"])["Profit"].sum()
df_group.sort_values(ascending=False)
df_group.plot.bar()
plt.show()

# %% [markdown]
# * <b>As it is clearly seen in the above visualization that states like California and New York has maximum profit whereas Texas and Ohioand has
# least profit among all the states of United States</b>

# %%
# visualization between sales and profit column

plt.figure(figsize=(20,10))
sb.scatterplot(df['Sales'],df['Profit'])
plt.show()

# %% [markdown]
# * <b>Here we observe that after a particular pointincrease in sales dosn't make that impact on profit.
#     As you can see above clearly when the sales is at the highest point profit is not that high. </b>

# %%
# visualization between ship mode and profit column

plt.figure(figsize=(10,10))
ship_profit=df.groupby(["Ship Mode"])["Profit"].sum()
ship_profit.sort_values(ascending=False)
ship_profit.plot.bar()
plt.show()

# %% [markdown]
# * <b>Standard class shipping mode is contributing more to increase the profit than other shipping modes</b>

# %%
# visualization between city and profit column

plt.figure(figsize=(10,10))
city_profit=df.groupby(["City"])["Profit"].sum()
a=city_profit[city_profit>3000]
a.sort_values(ascending=False)
a.plot.bar()
plt.show()

# %% [markdown]
# * <b>From above visualisation we conclude that New York city is contributing highest to increase the profit that the rest of the cities </b>

# %%
# visualization between Region and profit column

plt.figure(figsize=(10,10))
ship_profit=df.groupby(["Region"])["Profit"].sum()
ship_profit.sort_values(ascending=False)
ship_profit.plot.bar()
plt.show()

# %% [markdown]
# * <b>By this bar graph we can clearly say that east and west regions contributing more on increasing the profit than rest two regions.</b>

# %% [markdown]
# <h4>Pairplot</h4>

# %%
sb.pairplot(df)
plt.show()

# %% [markdown]
# #### Check the correlation between numeric data

# %%
cor_matrix=df.corr()

# %%
plt.figure(figsize=(20,10))
sb.heatmap(cor_matrix,annot=True)
plt.show()

# %% [markdown]
# #### Important points to make more profit.

# %% [markdown]
# * <B>With the help of heap map we can see the correlaton between sales and profit.</B>
# * <b>Discount is not that affecting on profit hence it should be taken care.Maybe by increasing it affects positive on profit.</b>
# * <b>we should be more careful about the central region as least profit seen there.</b>
